# %%
import numpy as np

# %%
N = 8
X = np.arange(0,N)

X_n = np.fft.fft(X)
X_n
# Out:
# array([28.+0.j        , -4.+9.65685425j, -4.+4.j        , -4.+1.65685425j,
#        -4.+0.j        , -4.-1.65685425j, -4.-4.j        , -4.-9.65685425j])
